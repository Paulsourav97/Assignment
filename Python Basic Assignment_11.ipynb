# %% [markdown]
# 1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.
#
# spam = -1
# assert spam>0 , "number is less than 0"
#
#
# 2. Write an assert statement that triggers an AssertionError if the variables
# eggs and bacon contain strings that are the same as each other,
# even if their cases are different
# (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).
#
# eggs = "hello"
# bacon = "Hello"
#
# assert eggs.lower() != bacon.lower(), "both are same error"
#
# 3. Create an assert statement that throws an AssertionError every time.
#
# assert False , "Always throws error"
#
#
# 4. What are the two lines that must be present in your software in order to call logging.debug()?
#
# import logging
# logging.basicConfig(filename = "myfile.log" , format = "%(asctime)s %(messages)s", filemode = 'w')
#
# 5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?
#
# import logging
# logging.basicConfig(filename = "myfile.log" , format = "%(asctime)s %(messages)s", filemode = 'w')
#
#
# 6. What are the five levels of logging?
#
# DEBUG
# INFO
# WARNING
# ERROR
# CRITICAL
#
# 7. What line of code would you add to your software to disable all logging messages?
#
# logging.disable()
#
#
# 8.Why is using logging messages better than using print() to display the same message?
#
# Logging is a means for tracking events that happens when a software works.
# In case the program fails it is difficult to debug a code that has print statements.
# Print statements will always fail for complex kind of codes.
#
#
#
# 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
#
# Step Into will cause the debugger to go into the next function call and break there.
# Step Over will tell the debugger to execute the next function and break afterwards.
# Step Out will tell the debugger to finish the current function and break after it.
#
#
# 10.After you click Continue, when will the debugger stop ?
#
# If we have set any break point.
# Or else it will stop after the execution of the program.
#
# 11. What is the concept of a breakpoint?
#
# A break point tells the python interpreter to pause execution at a
# particular point in the application.
